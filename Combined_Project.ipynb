# %%
h_word =  {'I':'நான்',
         'Am':'நான் ' ,
         'Do':'செய்' ,
         'Go':'போ' ,
         'He':'அவர்' ,
         'Me':'என்னை' ,
         'My':'என்' ,
         'No':'இல்லை' ,
         'On':'அன்று' ,
         'Or':'அல்லது' ,
         'So':'அதனால்' ,
         'Up':'	வரை' ,
         'We':'நாங்கள்' ,
         'Act':'நாடகம்' ,
         'Add':'கூட்டு' ,
         'Age':'வயது' ,
         'Aim':'நோக்கம்' ,
         'Air':'காற்று' ,
         'All':'அனைத்து' ,
         'And':'மற்றும்' ,
         'Ant':'எறும்பு' ,
         'Any':'ஏதேனும்' , 
         'Ask':'கேட்க' ,
         'Bad':'மோசமான' ,
         'Big':'பெரிய' ,
         'Buy':'வாங்க' ,
         'Cry':'கலங்குவது' ,
         'Dam':'அணை' ,
         'Dry':'இறக்கின்றன' ,
         'Die':'உலர்' ,
         'End':'முடிவு' ,
         'Ear':'காது' ,
         'Eat':'சாப்பிடு' ,
         'Egg':'முட்டை' ,
         'Eye':'கண்' ,
         'Fat':'கொழுப்பு' ,
         'Fly':'ஈ' ,
         'Fun':'வேடிக்கை' ,
         'Get':'பெறு' ,
         'God':'இறைவன்' ,
         'Hen':'கோழி' ,
         'Hot':'சூடான' ,
         'Job':'வேலை' ,
         'Leg':'கால்' ,
         'Lie':'பொய்' ,
         'Low':'குறைந்த' ,
         'Mad':'பைத்தியம்' ,
         'Man':'மனிதன்' ,
         'Not':'இல்லை' ,
         'Now':'இப்போது' ,
         'New':'புதிய' ,
         'Old':'பழைய' ,
         'Own':'சொந்தம்' ,
         'Run':'ஓடு' ,
         'Sad':'வருத்தம்' ,
         'Sea':'கடல்' ,
         'See':'பார்க்க' ,
         'Shy':'கூச்சமுடைய' ,
         'Sit':'உட்கார' ,
         'Sum':'தொகை' ,
         'Sun':'சூரியன்' ,
         'Tax':'வரி' , 
         'Try':'முயற்சி' ,
         'Use':'பயன்படுத்த' ,
         'War':'போர்' ,
         'Wet':'ஈரமான' ,
         'Who':'யார்' ,
         'Why':'ஏன்' ,
         'Win':'வெற்றி' ,
         'Also':'மேலும்' ,
         'Baby':'குழந்தை' ,
         'Back':'மீண்டும்' ,
         'Bake':'சுட்டுக்கொள்ள' ,
         'Bald':'வழுக்கை' ,
         'Ball':'பந்து' ,
         'Bark':'பட்டை' ,
         'Bath':'குளியல்' ,
         'Beet':'கிழங்கு' ,
         'Bend':'வளைவு',
         'Best':'சிறந்த' ,
         'Bird':'பறவை' ,
         'Bold':'தைரியமான' ,
         'Bone':'எலும்பு' ,
         'Book':'நூல்' ,
         'Born':'பிறந்தார்' ,
         'Both':'இரண்டும்' ,
         'Busy':'பரபரப்பு' ,
         'Call':'அழைப்பு' ,
         'Calm':'அமைதியான' ,
         'Care':'பராமரிப்பு' ,       
         'Come':'வாருங்கள்' ,
         'Cost':'செலவு' ,
         'Cute':'அழகான' ,
         'Crow':'காகம்' ,
         'Dare':'தைரியம்' ,
         'Dark':'இருள்' ,
         'Date':'தேதி' ,
         'Deal':'ஒப்பந்தம்' ,
         'Diet':'உணவுமுறை' ,
         'Dish':'சிறு தட்டு' ,
         'Door':'கதவு' ,
         'Down':'கீழ்' ,
         'Dust':'தூசி' ,
         'Each':'ஒவ்வொன்றும்' ,
         'Earn':'சம்பாதி' ,
         'Easy':'சுலபம்' ,
         'Edge':'விளிம்பு' ,
         'Evil':'தீய' ,
         'Exit':'வெளியேறு' ,
         'Face':'முகம்' ,
         'Fact':'உண்மை' ,
         'Fair':'நியாயமான' ,
         'Fake':'போலி' ,
         'Farm':'பண்ணை' ,
         'Fast':'வேகமாக' ,
         'Fear':'பயம்' ,
         'Feel':'உணர்கிறேன்' , 
         'Find':'கண்டுபிடிக்க' ,
         'Fine':'நன்றாக' ,
         'Fish':'மீன்' ,
         'Food':'உணவு' ,
         'Fool':'முட்டாள்' ,
         'Free':'இலவசம்' ,
         'Frog':'தவளை' ,
         'Full':'முழு' ,
         'Gape':'இடைவெளி' ,
         'Gift':'பரிசு' , 
         'Girl':'பெண்' ,
         'Goat':'வெள்ளாடு' , 
         'Good':'நல்ல' , 
         'Grab':'பிடி' ,
         'Grow':'வளர' ,
         'Half':'பாதி' ,
         'Hate':'வெறுக்கிறேன்' ,
         'Head':'தலை' ,
         'Hear':'கேள்' , 
         'Heat':'வெப்பம்' ,
         'Help':'உதவி' ,
         'Here':'இங்கே' ,
         'Hide':'மறைக்க' ,
         'High':'உயர்' ,
         'Hold':'பிடி' , 
         'Hole':'துளை' ,
         'Home':'வீடு' ,
         'Huge':'மிகப்பெரிய' ,
         'Hurt':'காயப்படுத்தியது' ,
         'Idea':'யோசனை' ,
         'Jump':'குதிக்க' ,
         'Just':'வெறும்' ,
         'Kill':'கொல்ல' , 
         'Land':'நிலம்' , 
         'Last':'கடந்த' ,
         'Late':'தாமதமாக' ,
         'Left':'விட்டு' ,
         'Life':'வாழ்க்கை' ,
         'Line':'வரி' ,
         'Lion':'சிங்கம்' ,
         'Long':'நீளமானது' ,
         'Look':'பார்' ,
         'Lost':'இழந்தது' ,
         'Love':'அன்பு' ,
         'Luck':'அதிர்ஷ்டம்' ,
         'Lung':'நுரையீரல்' ,
         'Many':'பல' ,
         'Meet':'சந்திக்க' ,
         'Melt':'உருகும்' ,
         'Milk':'பால்' , 
         'Must':'வேண்டும்' ,
         'Name':'பெயர்' ,
         'Near':'அருகில்' ,
         'Neat':'சுத்தமாக' ,
         'Neck':'கழுத்து' ,
         'Need':'தேவை' ,
         'Next':'அடுத்தது' , 
         'Only':'மட்டுமே' , 
         'Pain':'வலி' ,
         'Pair':'ஜோடி' ,
         'Park':'பூங்கா' ,
         'Path':'பாதை' ,
         'Play':'விளையாடு' , 
         'Poor':'ஏழை' ,
         'Pull':'இழுக்க' ,
         'Pure':'தூய்மையான' ,
         'Quit':'விட்டுவிட' ,
         'Quiz':'வினாடி வினா' ,
         'Race':'இனம்' ,
         'Rain':'மழை' ,
         'Rare':'அரிதான' ,
         'Real':'உண்மையான' ,
         'Rent':'வாடகை' ,
         'Rest':'ஓய்வு' , 
         'Rich':'பணக்கார' ,
         'Ride':'சவாரி' ,
         'Rise':'உயர்வு' ,
         'Risk':'ஆபத்து' ,
         'Room':'அறை' ,
         'Rope':'கயிறு' ,
         'Rude':'முரட்டுத்தனமான' ,
         'Sage':'முனிவர்' ,
         'Sail':'படகோட்டம்' ,
         'Salt':'உப்பு' ,
         'Same':'அதே' ,
         'Sand':'மணல்' ,
         'Save':'சேமிக்க' ,
         'Scam':'ஊழல்' ,
         'Seed':'விதை' ,
         'Seek':'தேடுங்கள்' ,
         'Self':'சுய' ,
         'Sell':'விற்க' ,
         'Send':'அனுப்புக' ,
         'Shop':'கடை' ,
         'Show':'நிகழ்ச்சி' ,
         'Sick':'உடம்பு சரியில்லை' ,
         'Side':'பக்கம்' ,
         'Site':'தளம்' ,
         'Size':'அளவு' ,
         'Skin':'தோல்' ,
         'Slow':'மெதுவாக' ,
         'Soft':'மென்மையான' ,
         'Soil':'மண்' ,
         'Some':'சில' ,
         'Soon':'விரைவில்' ,
         'Stay':'தங்க' ,
         'Stop':'நிறுத்து' ,
         'Such':'அத்தகைய' ,
         'Swap':'இடமாற்று' ,
         'Swim':'நீந்த' ,
         'Take':'எடுத்துக்கொள்' ,
         'Talk':'பேசு' ,
         'Tall':'உயரமான' ,
         'Team':'அணி' ,
         'Tell':'சொல்லுங்கள்' ,
         'Tent':'கூடாரம்' ,
         'That':'அந்த' ,
         'Then':'பிறகு' ,
         'Thin':'மெல்லிய' ,    
         'This':'இது' ,
         'Tide':'அலை' ,
         'Time':'நேரம்' ,
         'Tour':'சுற்றுப்பயணம்' ,
         'Town':'நகரம்' ,
         'Tree':'மரம்' ,
         'Trip':'பயணம்' ,
         'Turn':'திரும்ப' ,
         'Ugly':'அசிங்கமான' ,
         'Vase':'குவளை' ,
         'Vein':'நரம்பு' ,
         'Very':'மிகவும்' ,
         'View':'பார்வை' ,
         'Wage':'கூலி' ,
         'Wait':'காத்திரு' ,
         'Wake':'எழுந்திரு' ,
         'Walk':'நட' ,
         'Wall':'சுவர்' ,
         'Want':'வேண்டும்' ,
         'Warm':'சூடான' ,
         'Warn':'எச்சரிக்கை' ,
         'Weak':'பலவீனமான' ,
         'Wear':'அணிய' ,
         'Week':'வாரம்' ,
         'Well':'நன்றாக' ,
         'Went':'சென்றார்' ,
         'What':'என்ன' ,
         'When':'எப்பொழுது' ,
         'Wide':'பரந்த' ,
         'Wife':'மனைவி' ,
         'Wild':'காட்டு' ,
         'Will':'விருப்பம்' ,
         'Wind':'காற்று' ,
         'Wine':'மது' ,
         'Wish':'விரும்பும்' ,
         'Wood':'மரம்' ,
         'Wool':'கம்பளி' ,
         'Word':'சொல்' ,
         'Work':'வேலை' ,
         'Worm':'புழு' ,
         'Yarn':'நூல்' ,
         'Your':'உங்கள்' ,
         'Zoom':'பெரிதாக்கு' ,
         'About':'பற்றி' ,
         'Above':'மேலே' ,
         'Adapt':'ஏற்ப' ,
         'Admit':'ஒப்புக்கொள்' ,
         'Adult':'வயது வந்தோர்' ,
         'After':'பிறகு' ,
         'Again':'மீண்டும்' ,
         'Agree':'ஒப்புக்கொள்' ,
         'Alert':'எச்சரிக்கை' ,
         'Allow':'அனுமதிக்க' ,
         'Alone':'தனியாக' ,
         'Along':'சேர்த்து' ,
         'Anger':'கோபம்' ,
         'Angle':'கோணம்' ,
         'Angry':'கோபம்' ,
         'Asset':'சொத்து' ,
         'Avoid':'தவிர்க்க' ,
         'Awake':'விழித்து' ,
         'Aware':'தெரியும்' ,
         'Begin':'தொடங்கும்' ,
         'Birth':'பிறப்பு' ,
         'Blood':'இரத்தம்' ,
         'Brain':'மூளை' ,
         'Built':'கட்டப்பட்டது' ,
         'Bring':'கொண்டு' ,
         'Build':'கட்ட' ,
         'Camel':'ஒட்டகம்' ,
         'Canal':'கால்வாய்' ,
         'Carry':'சுமந்து செல்' ,
         'Cheap':'மலிவான' ,
         'Cheat':'ஏமாற்று' ,
         'Check':'காசோலை' ,
         'Chest':'மார்பு' ,
         'Claim':'கூற்று' ,
         'Clean':'சுத்தமான' ,
         'Clear':'தெளிவானது' ,
         'Climb':'ஏற' ,
         'Close':'நெருக்கமான' ,
         'Cloth':'துணி' ,
         'Cloud':'மேகம்' ,
         'Color':'நிறம்' ,
         'Crime':'குற்றம்' ,
         'Crowd':'கூட்டம்' ,
         'Crown':'கிரீடம்' ,
         'Daily':'தினசரி' ,
         'Dance':'நடனம்' ,
         'Death':'இறப்பு' ,
         'Decay':'சிதைவு' ,
         'Delay':'தாமதம்' ,
         'Devil':'பிசாசு' ,
         'Dirty':'அழுக்கு' ,
         'Dress':'ஆடை' ,
         'Drink':'பானம்' ,
         'Drive':'ஓட்டு' ,
         'Dwell':'வசிக்க' ,
         'Eager':'ஆவலுடன்' ,
         'Eagle':'கழுகு' ,
         'Early':'ஆரம்ப' ,
         'Earth':'பூமி' ,
         'Elder':'மூத்தவர்' ,
         'Empty':'காலியாக' ,
         'Enemy':'எதிரி' ,
         'Enjoy':'அனுபவிக்க' ,
         'Entry':'நுழைவு' ,
         'Equal':'சமமான' ,
         'Essay':'கட்டுரை' ,
         'Event':'நிகழ்வு' ,
         'Every':'ஒவ்வொரு' ,
         'Exact':'சரியான' ,
         'Exist':'உள்ளன' ,
         'Extra':'கூடுதல்' ,
         'Faith':'நம்பிக்கை' ,
         'Fault':'தவறு' ,
         'Fever':'காய்ச்சல்' ,
         'Field':'களம்' ,
         'Final':'இறுதி' ,
         'Fleet':'கடற்படை' ,
         'Float':'மிதவை' ,
         'Flood':'வெள்ளம்' ,
         'Floor':'தரை' ,
         'Flour':'மாவு' ,
         'Fluid':'திரவம்' ,
         'Focus':'கவனம்' ,
         'Force':'படை' ,
         'Fraud':'மோசடி' ,
         'Fresh':'புதியது' ,
         'Front':'முன்' ,
         'Fruit':'பழம்' ,
         'Ghost':'பேய்' ,
         'Globe':'பூகோளம்' ,
         'Going':'போகிறது' ,
         'Grain':'தானியம்' ,
         'Grant':'மானியம்' ,
         'Grass':'புல்' ,
         'Great':'நன்று' ,
         'Group':'குழு' ,
         'Guard':'காவலர்' ,
         'Guest':'விருந்தினர்' ,
         'Habit':'பழக்கம்' ,
         'Heart':'இதயம்' ,
         'Honey':'தேன்' ,
         'Horse':'குதிரை' ,
         'House':'வீடு' ,
         'Human':'மனிதன்' ,
         'Ideal':'ஏற்றதாக' ,
         'Issue':'பிரச்சினை' ,
         'Judge':'நீதிபதி' , 
         'Knife':'கத்தி' ,
         'Labor':'தொழிலாளர்' , 
         'Ladle':'அகப்பை' ,
         'Large':'பெரிய' ,
         'Laugh':'சிரிக்கவும்' ,
         'Learn':'அறிய' ,
         'Leave':'விடு' ,
         'Legal':'சட்டபூர்வமான' ,
         'Limit':'அளவு' ,
         'Lunch':'மதிய உணவு' ,
         'Metal':'உலோகம்' ,
         'Mixed':'கலந்தது' ,
         'Money':'பணம்' ,
         'Month':'மாதம்' ,
         'Mount':'ஏற்ற' ,
         'Mouth':'வாய்' ,
         'Music':'இசை' ,
         'Maize':'சோளம்' ,
         'Naked':'நிர்வாணமாக' ,
         'Never':'ஒருபோதும்' ,
         'Night':'இரவு' ,
         'Niece':'மருமகள்' ,
         'Noise':'சத்தம்' ,
         'Occur':'ஏற்படும்' ,
         'Ocean':'கடல்' ,
         'Onion':'வெங்காயம்' ,
         'Offer':'சலுகை' ,
         'Order':'உத்தரவு' ,
         'Organ':'உறுப்பு' ,
         'Other':'மற்றவை' ,
         'Owner':'உரிமையாளர்' ,
         'Paddy':'நெல்' ,
         'Panic':'பீதி' ,
         'Peace':'சமாதானம்' ,
         'Place':'இடம்' ,
         'Plant':'ஆலை' ,
         'Price':'விலை' ,
         'Pride':'பெருமை' ,
         'Proud':'பெருமை' ,
         'Prove':'நிரூபிக்க' , 
         'Quilt':'மெல்லிய மெத்தை' ,
         'Quick':'விரைவான' ,
         'Quite':'மிகவும்' ,
         'Raise':'உயர்த்த' ,
         'Reach':'அடைய' ,
         'React':'எதிர்வினை' ,
         'Ready':'தயார்' ,
         'Reply':'பதில்' ,
         'Right':'சரி' ,
         'Round':'சுற்று' ,
         'Rural':'கிராமப்புற' ,
         'Saint':'புனிதர்' ,
         'Scope':'வாய்ப்பு' ,
         'Score':'மதிப்பெண்' ,
         'Sense':'உணர்வு' ,
         'Shake':'குலுக்கல்' ,
         'Shape':'வடிவம்' ,
         'Share':'பகிர்' ,
         'Sharp':'கூர்மையான' ,
         'Shrub':'புதர்' ,
         'Skill':'திறமை' ,
         'Sleep':'தூங்கு' ,
         'Slope':'சாய்வு' ,
         'Small':'சிறிய' ,
         'Smell':'வாசனை' ,
         'Smile':'புன்னகை' ,
         'Snake':'பாம்பு' ,
         'Snore':'குறட்டை' ,
         'Solid':'திடமான' ,
         'Sound':'ஒலி' ,
         'Space':'விண்வெளி' ,
         'Speak':'பேசு' ,
         'Speed':'வேகம்' ,
         'Spend':'செலவு' ,
         'Spent':'செலவழித்தது' ,
         'Sperm':'விந்து' ,
         'Sport':'விளையாட்டு' , 
         'Stand':'நிற்க' ,
         'Steam':'நீராவி' ,
         'Stone':'கல்' ,
         'Story':'கதை' ,
         'Taste':'சுவை' ,
         'Teach':'கற்பிக்கின்றன' ,
         'Teeth':'பற்கள்' ,
         'Thank':'நன்றி' ,
         'There':'அங்கு' ,
         'These':'இவை' ,
         'Thick':'தடித்த' , 
         'Thing':'விஷயம்' ,
         'Tiger':'புலி' ,
         'Today':'இன்று' ,
         'Total':'மொத்தம்' ,
         'Treat':'சிகிச்சை' ,
         'Trend':'போக்கு' ,
         'Tried':'முயற்சித்தார்' ,
         'Trust':'நம்பிக்கை' ,
         'Truth':'உண்மை' ,
         'Twice':'இரண்டு முறை' ,
         'Under':'கீழ்' ,
         'Upper':'மேல்' ,
         'Urban':'நகர்ப்புற' ,
         'Visit':'வருகை' ,
         'Voice':'குரல்' ,
         'Vomit':'வாந்தி' ,
         'Waste':'கழிவு' ,
         'Water':'தண்ணீர்' ,
         'Wheat':'கோதுமை' ,
         'Where':'எங்கே' ,
         'White':'வெள்ளை' ,
         'Whole':'முழுவதும்' ,
         'Woman':'பெண்' ,
         'World':'உலகம்' ,
         'Worst':'மோசமான' ,
         'Write':'எழுது' ,
         'Wrong':'தவறு' ,
         'Yield':'விளைச்சல்' ,
         'Young':'இளம்' ,
         'Youth':'இளைஞர்கள்'}

# %%
h_key=[]
for i in h_word.keys():
  h_key.append(i.strip())

# %%
h_key
# Out:
# ['I',
#  'Am',
#  'Do',
#  'Go',
#  'He',
#  'Me',
#  'My',
#  'No',
#  'On',
#  'Or',
#  'So',
#  'Up',
#  'We',
#  'Act',
#  'Add',
#  'Age',
#  'Aim',
#  'Air',
#  'All',
#  'And',
#  'Ant',
#  'Any',
#  'Ask',
#  'Bad',
#  'Big',
#  'Buy',
#  'Cry',
#  'Dam',
#  'Dry',
#  'Die',
#  'End',
#  'Ear',
#  'Eat',
#  'Egg',
#  'Eye',
#  'Fat',
#  'Fly',
#  'Fun',
#  'Get',
#  'God',
#  'Hen',
#  'Hot',
#  'Job',
#  'Leg',
#  'Lie',
#  'Low',
#  'Mad',
#  'Man',
#  'Not',
#  'Now',
#  'New',
#  'Old',
#  'Own',
#  'Run',
#  'Sad',
#  'Sea',
#  'See',
#  'Shy',
#  'Sit',
#  'Sum',
#  'Sun',
#  'Tax',
#  'Try',
#  'Use',
#  'War',
#  'Wet',
#  'Who',
#  'Why',
#  'Win',
#  'Also',
#  'Baby',
#  'Back',
#  'Bake',
#  'Bald',
#  'Ball',
#  'Bark',
#  'Bath',
#  'Beet',
#  'Bend',
#  'Best',
#  'Bird',
#  'Bold',
#  'Bone',
#  'Book',
#  'Born',
#  'Both',
#  'Busy',
#  'Call',
#  'Calm',
#  'Care',
#  'Come',
#  'Cost',
#  'Cute',
#  'Crow',
#  'Dare',
#  'Dark',
#  'Date',
#  'Deal',
# ...

# %%
h_value=[]
for i in h_word.values():
  h_value.append(i.strip())

# %%
h_value
# Out:
# ['நான்',
#  'நான்',
#  'செய்',
#  'போ',
#  'அவர்',
#  'என்னை',
#  'என்',
#  'இல்லை',
#  'அன்று',
#  'அல்லது',
#  'அதனால்',
#  'வரை',
#  'நாங்கள்',
#  'நாடகம்',
#  'கூட்டு',
#  'வயது',
#  'நோக்கம்',
#  'காற்று',
#  'அனைத்து',
#  'மற்றும்',
#  'எறும்பு',
#  'ஏதேனும்',
#  'கேட்க',
#  'மோசமான',
#  'பெரிய',
#  'வாங்க',
#  'கலங்குவது',
#  'அணை',
#  'இறக்கின்றன',
#  'உலர்',
#  'முடிவு',
#  'காது',
#  'சாப்பிடு',
#  'முட்டை',
#  'கண்',
#  'கொழுப்பு',
#  'ஈ',
#  'வேடிக்கை',
#  'பெறு',
#  'இறைவன்',
#  'கோழி',
#  'சூடான',
#  'வேலை',
#  'கால்',
#  'பொய்',
#  'குறைந்த',
#  'பைத்தியம்',
#  'மனிதன்',
#  'இல்லை',
#  'இப்போது',
#  'புதிய',
#  'பழைய',
#  'சொந்தம்',
#  'ஓடு',
#  'வருத்தம்',
#  'கடல்',
#  'பார்க்க',
#  'கூச்சமுடைய',
#  'உட்கார',
#  'தொகை',
#  'சூரியன்',
#  'வரி',
#  'முயற்சி',
#  'பயன்படுத்த',
#  'போர்',
#  'ஈரமான',
#  'யார்',
#  'ஏன்',
#  'வெற்றி',
#  'மேலும்',
#  'குழந்தை',
#  'மீண்டும்',
#  'சுட்டுக்கொள்ள',
#  'வழுக்கை',
#  'பந்து',
#  'பட்டை',
#  'குளியல்',
#  'கிழங்கு',
# ...

# %%
h_word={h_key[i]:h_value[i] for i in range(len(h_key))}

# %%
h_word
# Out:
# {'I': 'நான்',
#  'Am': 'நான்',
#  'Do': 'செய்',
#  'Go': 'போ',
#  'He': 'அவர்',
#  'Me': 'என்னை',
#  'My': 'என்',
#  'No': 'இல்லை',
#  'On': 'அன்று',
#  'Or': 'அல்லது',
#  'So': 'அதனால்',
#  'Up': 'வரை',
#  'We': 'நாங்கள்',
#  'Act': 'நாடகம்',
#  'Add': 'கூட்டு',
#  'Age': 'வயது',
#  'Aim': 'நோக்கம்',
#  'Air': 'காற்று',
#  'All': 'அனைத்து',
#  'And': 'மற்றும்',
#  'Ant': 'எறும்பு',
#  'Any': 'ஏதேனும்',
#  'Ask': 'கேட்க',
#  'Bad': 'மோசமான',
#  'Big': 'பெரிய',
#  'Buy': 'வாங்க',
#  'Cry': 'கலங்குவது',
#  'Dam': 'அணை',
#  'Dry': 'இறக்கின்றன',
#  'Die': 'உலர்',
#  'End': 'முடிவு',
#  'Ear': 'காது',
#  'Eat': 'சாப்பிடு',
#  'Egg': 'முட்டை',
#  'Eye': 'கண்',
#  'Fat': 'கொழுப்பு',
#  'Fly': 'ஈ',
#  'Fun': 'வேடிக்கை',
#  'Get': 'பெறு',
#  'God': 'இறைவன்',
#  'Hen': 'கோழி',
#  'Hot': 'சூடான',
#  'Job': 'வேலை',
#  'Leg': 'கால்',
#  'Lie': 'பொய்',
#  'Low': 'குறைந்த',
#  'Mad': 'பைத்தியம்',
#  'Man': 'மனிதன்',
#  'Not': 'இல்லை',
#  'Now': 'இப்போது',
#  'New': 'புதிய',
#  'Old': 'பழைய',
# ...

# %%
k_word={"word": "சொல்",
    "hello": "வணக்கம்",
    "world": "உலகம்",
    "goodbye": "பிரியாவிடம்",
    "thank you": "நன்றி",
    "please": "தயவுசெய்து",
    "yes": "ஆம்",
    "no": "இல்லை",
    "happy": "மகிழ்ச்சி",
    "sad": "துக்கம்",
    "love": "காதல்",
    "friend": "நண்பர்",
    "family": "குடும்பம்",
    "home": "வீடு",
    "work": "வேலை",
    "play": "விளையாடு",
    "eat": "சாப்பிடு",
    "drink": "குடி",
    "sleep": "தூங்கு",
    "run": "ஓடு",
    "walk": "நட",
    "jump": "ஆடு",
    "swim": "பயணம்",
    "read": "வாசி",
    "write": "எழுது",
    "listen": "கேளு",
    "speak": "பேசு",
    "learn": "கற்றுக்கொள்",
    "understand": "புரிந்துகொள்",
    "think": "சிந்தி",
    "create": "உருவாக்கு",
    "imagine": "கண்டிப்பாக்கு",
    "explore": "ஆராயு",
    "discover": "கண்டறி",
    "solve": "தீர்",
    "challenge": "சவால்",
    "success": "வெற்றி",
    "failure": "தோல்வி",
    "beautiful": "அழகான",
    "ugly": "மீண்டும்",
    "big": "பெரிய",
    "small": "சிறிய",
    "hot": "சூடான",
    "cold": "சீண்டு",
    "bright": "ஒளிர",
    "dark": "இருக்காத",
    "new": "புதிய",
    "old": "பழைய",
    "happy": "மகிழ்ச்சியான",
    "sad": "துக்கமான",
    "strong": "வலிமையான",
    "weak": "மெதுவான",
    "fast": "வேகமான",
    "slow": "மெதுவான",
    "smart": "போன்ற",
    "stupid": "முட்டாள்தனமான",
    "brave": "தடையில்லாத",
    "fearful": "பயமுடன்",
    "kind": "அன்புள்ள",
    "mean": "மேன்",
    "generous": "உதவி",
    "selfish": "சொந்த",
    "honest": "நேர்மையான",
    "dishonest": "மொழி",
    "healthy": "ஆரோக்கிய",
    "sick": "நீரிழிவு",
    "clean": "தொலைந்த",
    "dirty": "கழுவும்",
    "simple": "எளிதான",
    "complex": "சூழ்நிலையான",
    "open": "திறந்த",
    "closed": "மூடப்பட்ட",
    "empty": "காலியான",
    "full": "முழுவதும்",
    "beautiful": "அழகான",
    "ugly": "மீண்டும்",
    "good": "நலமான",
    "bad": "மொழிபெயர்ந்த",
    "right": "சரி",
    "wrong": "தவறான",
    "true": "உண்மையான",
    "false": "பொய்யான",
    "day": "நாள்",
    "night": "இரவு",
    "sun": "சூரியன்",
    "moon": "மாதிரி",
    "star": "நக்கினம்",
    "sky": "வானம்",
    "earth": "பூமி",
    "water": "நீர்",
    "fire": "தீ",
    "air": "வாயு",
    "tree": "மரம்",
    "flower": "மலர்",
    "bird": "பறவை",
    "animal": "விலங்கு",
    "dog": "நாய்",
    "cat": "பூனை",
    "cow": "பசு",
    "horse": "ஆடு",
    "elephant": "யானை",
    "snake": "பாம்பு",
    "fish": "மீன்",
    "food": "உணவு",
    "drink": "குடி",
    "fruit": "பழம்",
    "vegetable": "காய்கறி",
    "bread": "ரொட்டி",
    "rice": "அரிசி",
    "meat": "மாம்சம்",
    "milk": "பால்",
    "sugar": "சர்க்கரை",
    "salt": "உப்பு",
    "spicy": "மசாலா",
    "sweet": "இனிப்பு",
    "bitter": "பச்சை",
    "sour": "புளிமிச்சல்",
    "friend": "நண்பர்",
    "enemy": "எதிரி",
    "teacher": "ஆசிரியர்",
    "student": "மாணவர்",
    "doctor": "மருத்துவர்",
    "engineer": "பொறியாளர்",
    "artist": "கலைஞர்",
    "writer": "எழுத்தாளர்",
    "actor": "நடிகர்",
    "singer": "பாடகர்",
    "dancer": "நடிப்பு",
    "police": "போலீஸ்",
    "soldier": "படையாளி",
    "country": "நாடு",
    "city": "நகரம்",
    "village": "கிராமம்",
    "school": "பள்ளி",
    "hospital": "மருத்துவமனை",
    "temple": "கோவில்",
    "church": "தேவாலயம்",
    "mosque": "மசூதி",
    "market": "சந்தை",
    "park": "பூங்கா",
    "beach": "கடற்கரை",
    "mountain": "மலை",
    "river": "ஆறு",
    "lake": "ஏரி",
    "forest": "காடு",
    "road": "சாலை",
    "car": "கார்",
    "bus": "போக்குவரத்து",
    "train": "ரயில்",
    "bicycle": "மிதிப்புச் சக்கரம்",
    "plane": "விமானம்",
    "ship": "படகு",
    "book": "புத்தகம்",
    "pen": "பேனா",
    "pencil": "முத்திரை",
    "paper": "காகிதம்",
    "computer": "கணினி",
    "phone": "தொலைபேசி",
    "television": "தொலைக்காட்சி",
    "camera": "கேமரா",
    "clock": "கடிகாரம்",
    "light": "ஒளி",
    "electricity": "மின்சாரம்",
    "battery": "பேட்டரி",
    "internet": "இணையம்",
    "email": "மின்னஞ்சல்",
    "message": "செய்தி",
    "website": "இணையதளம்",
    "social": "சமூக",
    "media": "மீடியா",
    "game": "விளையாட்டு",
    "music": "இசை",
    "movie": "திரைப்படம்",
    "art": "கலை",
    "science": "அறிவியல்",
    "mathematics": "கணிதம்",
    "history": "வரலாறு",
    "geography": "புவியியல்",
    "language": "மொழி",
    "culture": "பண்பாடு",
    "religion": "மதம்",
    "politics": "அரசியல்",
    "economy": "பொருளாதாரம்",
    "apple": "ஆப்பிள்",
    "banana": "வாழைப்பழம்",
    "orange": "ஆரஞ்சு",
    "mango": "மாம்பழம்",
    "grapes": "திராட்சை",
    "strawberry": "ஸ்ட்ராபெரி",
    "pineapple": "அன்னாசிப்பழம்",
    "watermelon": "தர்பூசணி",
    "papaya": "பப்பாளி",
    "jackfruit": "பலாப்பழம்",
    "clock": "கடிகாரம்",
    "table": "மேடை",
    "chair": "முட்டை",
    "bed": "படுக்களம்",
    "cup": "கப்",
    "plate": "தட்டி",
    "spoon": "சண்டை",
    "fork": "முள்ளை",
    "knife": "கத்தி",
    "car": "கார்",
    "bicycle": "பைசிகிள்",
    "motorcycle": "மோட்டார்சைக்கிள்",
    "bus": "பேருந்து",
    "train": "ரயில்",
    "airplane": "விமானம்",
    "ship": "கப்பல்",
    "school": "பள்ளி",
    "college": "கல்லூரி",
    "hospital": "மருத்துவமனை",
    "library": "நூலகம்",
    "park": "பூங்கா",
     "week": "வாரம்",
    "month": "மாதம்",
    "year": "ஆண்டு",
    "sunrise": "சூரியோதயம்",
    "sunset": "சூரியாஸ்தமனம்",
    "music": "இசை",
    "dance": "ஆடல்",
    "art": "கலை",
    "film": "திரைப்படம்",
    "song": "பாடல்",
    "game": "விளையாட்டு",
    "sports": "விளையாட்டுகள்",
    "travel": "பயணம்",
    "adventure": "சாதனை",
    "nature": "இயல்பு",
    "beauty": "அழகு",
    "peace": "சமாதானம்",
    "happiness": "மகிழ்ச்சி",
    "success": "வெற்றி",
    "knowledge": "அறிவு",
    "wisdom": "ஞானம்",
    "health": "ஆரோக்கியம்",
    "dream": "கனவு",
    "hope": "நம்பிக்கை",
    "faith": "நம்பிக்கை",
    "courage": "தவம்",
    "kindness": "அன்பு",
    "respect": "மரியாதை",
    "freedom": "விடுதலை",
    "equality": "சமத்துவம்",
    "justice": "நீதி",
    "peace": "சமாதானம்",
    "truth": "உண்மை",
    "forgiveness": "மன்னிப்பு",
    "patience": "தாமரை",
    "strength": "வலியுறுத்தல்",
    "beauty": "அழகு",
    "intelligence": "புதிய",
    "creativity": "உருவாக்கம்",
    "passion": "ஆர்வம்",
    "ambition": "லட்சியை",
    "purpose": "நோக்கம்",
    "inspiration": "மனதிற்காக",
    "imagination": "கனவுகள்",
    "kindness": "அன்பு",
    "compassion": "கருணை",
    "generosity": "உதவி",
    "gratitude": "நன்றி",
    "joy": "மகிழ்ச்சி",
    "laughter": "சிரிப்பு",
    "celebration": "கொண்டாட்டம்",
    "friendship": "நண்பர்கள்",
    "family": "குடும்பம்",
    "peace": "சமாதானம்",
    "harmony": "ஒன்றிணைப்பு",
    "unity": "ஒன்றிணைப்பு",
    "progress": "முன்னேற்றம்",
    "development": "மேம்பாடு",
    "innovation": "முதன்மை",
    "technology": "தொழில்நுட்பம்",
    "science": "அறிவியல்",
    "environment": "சூழல்",
    "sustainability": "மீண்டும் பயன்படுத்தும் முடிவு",
    "climate": "காற்றின் நிலை",
    "education": "கல்வி",
    "knowledge": "அறிவு",
    "wisdom": "ஞானம்",
    "learning": "கற்றல்",
    "growth": "வளர்ச்சி",
    "success": "வெற்றி",
    "achievement": "முடிவு",
    "challenge": "சவால்",
    "opportunity": "அவகாசம்",
    "perseverance": "தாமரையாக",
    "motivation": "உத்தேசம்",
    "inspiration": "மனதிற்காக",
    "dedication": "பதில்",
    "discipline": "அமைதி",
    "balance": "நிலை",
    "focus": "கவனம்",
    "effort": "முயற்சி",
    "resilience": "திடீர்மானம்",
    "patience": "தாமரை",
    "self-confidence": "சுயமரியாதை",
    "self-improvement": "சுயவருத்தம்",
    "self-reflection": "சுயசார்ந்திரம்",
    "self-care": "சுயாதாரம்",
    "happiness": "மகிழ்ச்சி",
    "fulfillment": "நிறைவு",
    "contentment": "முக்கியமானது",
    "gratitude": "நன்றி",
    "abundance": "பெருமை",
    "simplicity": "எளிதில்",
    "freedom": "விடுதலை",
    "peace": "சமாதானம்",
    "love": "காதல்",
    "compassion": "கருணை",
    "kindness": "அன்பு",
    "generosity": "உதவி",
    "respect": "மரியாதை",
    "integrity": "மெழுமொழி",
    "ethics": "நன்மை",
    "empathy": "உணர்வு",
    "forgiveness": "மன்னிப்பு",
    "tolerance": "மரியாதை",
    "justice": "நீதி",
    "wisdom": "ஞானம்",
    "humility": "அண்ணாவின் அமைதியை",
    "faith": "நம்பிக்கை",
    "hope": "நம்பிக்கை",
    "patience": "தாமரை",
    "perseverance": "தவம்",
    "courage": "தவம்",
    "strength": "வலியுறுத்தல்",
    "growth": "வளர்ச்சி",
    "change": "மாற்றம்",
    "challenge": "சவால்",
    "opportunity": "அவகாசம்",
    "adventure": "சாதனை",
    "experience": "அனுபவம்",
    "achievement": "முடிவு",
    "success": "வெற்றி",
    "reflection": "சரிபார்த்தல்",
    "inspiration": "மனதிற்காக",
    "motivation": "உத்தேசம்",
    "dream": "கனவு",
    "ambition": "லட்சியை",
    "purpose": "நோக்கம்",
    "passion": "ஆர்வம்",
    "creativity": "உருவாக்கம்",
    "innovation": "முதன்மை",
    "imagination": "கனவுகள்",
    "curiosity": "ஆர்வம்",
    "knowledge": "அறிவு",
    "learning": "கற்றல்",
    "education": "கல்வி",
    "wisdom": "ஞானம்",
    "intelligence": "புதிய",
    "science": "அறிவியல்",
    "technology": "தொழில்நுட்பம்",
    "communication": "தொடர்பு",
    "collaboration": "ஒழுக்கமைப்பு",
    "teamwork": "அணி வேலை",
    "leadership": "முன்னணி",
    "creativity": "உருவாக்கம்",
    "innovation": "முதன்மை",
    "problem-solving": "பிரச்சினை தீர்க்கும் முறை",
    "critical-thinking": "முக்கிய சிக்கல் கருத்து",
    "adaptability": "மாற்றம் ஏற்படுத்துதல்",
    "resilience": "திடீர்மானம்",
    "emotional-intelligence": "உணர்வியல் புரிவம்",
    "time-management": "நேர மேலாண்மை",
    "prioritization": "முன்னுரிமைத்தல்",
    "organizational-skills": "அமைப்பு திறன்கள்",
    "attention-to-detail": "விருத்த குறிப்பு",
    "decision-making": "முடிவு எடுக்குதல்",
    "problem-solving": "பிரச்சினை தீர்க்கும் முறை",
    "negotiation": "சந்தா",
    "conflict-resolution": "மீறுதல் தீர்வு",
    "customer-service": "வாடிக்கையாளர் சேவை",
    "sales": "விற்பனை",
    "marketing": "மின்னணுவியல்",
    "financial-literacy": "நிதியியல் அறிவியல்",
    "entrepreneurship": "தொழில்நுட்பம்",
    "networking": "பிணைப்பு",
    "camera": "கேமரா",
    "headphones": "தலைப்புமொழிவு",
    "speakers": "வானொலி",
    "microphone": "மைக்ரோஃபோன்",
    "printer": "அச்சுப் பிரின்டர்",
    "keyboard": "விசைப்பலகை",
    "mouse": "மோவுஸ்",
    "router": "ரூட்டர்",
    "modem": "மோடம்",
    "hard drive": "மின்னணு இயந்திரம்",
    "solid-state drive": "நிலையான நிலை இயந்திரம்",
    "memory card": "நினைவக அட்டை",
    "power bank": "மின்னணு வங்கி",
    "virtual reality headset": "மெய்ப்பொருள் முகத்திரை",
    "drones": "கனவு உணவுப்பூச்சி",
    "smart home devices": "ஸ்மார்ட் வீட்டு சாதனங்கள்",
    "gaming console": "விளையாட்டு கன்சோல்",
    "wearable devices": "அணிந்து திரும்பும் சாதனங்கள்",
    "fitness tracker": "முகப்பு கணிக்கீட்டு",
    "e-reader": "மின்னஞ்சல் வாசிப்பு சாதனம்",
    "gaming mouse": "விளையாட்டு மோவுஸ்",
    "action camera": "செயல்பாட்டு கேமரா",
    "smart speaker": "ஸ்மார்ட் வானொலி",
    "robot vacuum cleaner": "தானியங்கி முதுகெலிப்பு சுத்தம்",
    "wireless earphones": "வாயில் மின்னஞ்சல் குறி",
    "smart thermostat": "ஸ்மார்ட் தவறான வெப்பமான மீன்பிரிப்பு சாதனம்",
     "smart home devices": "ஸ்மார்ட் வீட்டு சாதனங்கள்",
    "smart bulb": "ஸ்மார்ட் பல்ப்",
    "smart thermostat": "ஸ்மார்ட் தவறான வெப்பமான மீன்பிரிப்பு சாதனம்",
    "drones": "முதலியவற்றில் ஒரு தூளம்",
    "smart doorbell": "ஸ்மார்ட் முகப்புத் தாக்கு",
    "wireless charger": "வயர்லெஸ் சார்ஜர்",
    "bluetooth speaker": "புளுத்தூதர் வானொலி",
    "action camera": "செயல்பாட்டு கேமரா",
    "e-reader": "மின்னஞ்சல் வாசிப்பு சாதனம்",
    "video game console": "வீடியோ விளையாட்டு கன்சோல்",
    "drones": "முதலியவற்றில் ஒரு தூளம்",
    "smart doorbell": "ஸ்மார்ட் முகப்புத் தாக்கு",
    "wireless charger": "வயர்லெஸ் சார்ஜர்",
    "bluetooth speaker": "புளுத்தூதர் வானொலி",
    "action camera": "செயல்பாட்டு கேமரா",
    "e-reader": "மின்னஞ்சல் வாசிப்பு சாதனம்",
    "video game console": "வீடியோ விளையாட்டு கன்சோல்",
    "gaming keyboard": "விளையாட்டு விசைப்பலகை",
    "dog": "நாய்",
    "cat": "பூனை",
    "lion": "சிங்கம்",
    "tiger": "புலி",
    "elephant": "யானை",
    "giraffe": "சிறுவாலி",
    "monkey": "குரங்கு",
    "bear": "கரடி",
    "deer": "மான்",
    "rabbit": "முயல்",
    "fox": "நரி",
    "wolf": "நாய்",
    "cow": "மாடு",
    "goat": "ஆடு",
    "sheep": "மோட்டை",
    "horse": "ஆடு",
    "donkey": "கழுதை",
    "pig": "பன்றி",
    "chicken": "கோழி",
    "duck": "வாத்து",
    "swan": "மந்தக் குரங்கு",
    "peacock": "மயில்",
    "parrot": "கிளி",
    "sparrow": "சிட்டுக்குருவி",
    "eagle": "கழுகு",
    "owl": "ஆந்தை",
    "snake": "பாம்பு",
    "crocodile": "முதலை",
    "turtle": "ஆமை",
    "sparrow": "சிட்டுக்குருவி",
    "pigeon": "புறா",
    "peacock": "மயில்",
    "parrot": "கிளி",
    "crow": "காகம்",
    "eagle": "கழுதை",
    "owl": "பருந்துக்குருவி",
    "flamingo": "பேலிக்கனி",
    "swan": "நெத்திப்பறவை",
    "duck": "வாத்து",
    "goose": "வாத்துப் பறவை",
    "peahen": "நாரை",
    "kingfisher": "மீன்பறவை",
    "woodpecker": "மரத்துக்குருவி",
    "penguin": "பெண்டுயின்",
    "swallow": "துண்டுப் பறவை",
    "seagull": "கடல்காற்றுக் குருவி",
    "cuckoo": "கோயில்",
    "robin": "ராபின்",
    "hummingbird": "ஹம்மிங்பூர்டு",
    "carrot": "கேரட்",
    "potato": "உருளைக்கிழங்கு",
    "tomato": "தக்காளி",
    "onion": "வெங்காயம்",
    "garlic": "பூண்டு",
    "ginger": "இஞ்சி",
    "cabbage": "முட்டைக்கோசு",
    "cauliflower": "பூக்கோசு",
    "brinjal": "கத்தரிக்காய்",
    "capsicum": "குடைமிளகாய்",
    "beetroot": "பீட்ரூட்",
    "radish": "முள்ளங்கி",
    "spinach": "பசலைக் கீரை",
    "bitter gourd": "பாவக்காய்",
    "ridge gourd": "பீர்க்கங்காய்",
    "ladies finger": "வெண்டைக்காய்",
    "pumpkin": "பரங்கிக்காய்",
    "cucumber": "வெள்ளரிக்காய்",
    "green peas": "பச்சை பட்டாணி",
    "beans": "பீன்ஸ்",
    "coriander": "கொத்துமல்லி",
    "curry leaves": "கறிவேப்பிலை",
    "mint": "புதினா",
    "lentils": "பருப்புக்கடலை",
    "green chilli": "பச்சை மிளகாய்",
    "corn": "மக்காச்சோளம்",
    "sweet potato": "சர்க்கரை வடிகாய்",
    "chennai": "சென்னை",
    "coimbatore": "கோயம்புத்தூர்",
    "madurai": "மதுரை",
    "tiruchirappalli": "திருச்சிராப்பள்ளி",
    "tirunelveli": "திருநெல்வேலி",
    "salem": "சேலம்",
    "tiruppur": "திருப்பூர்",
    "erode": "ஈரோடு",
    "vellore": "வேலூர்",
    "thoothukudi": "தூத்துக்குடி",
    "thanjavur": "தஞ்சாவூர்",
    "dindigul": "திண்டுக்கல்",
    "virudhunagar": "விருதுநகர்",
    "sivaganga": "சிவகங்கை",
    "tirupathur": "திருப்பத்தூர்",
    "namakkal": "நாமக்கல்",
    "krishnagiri": "கிருஷ்ணகிரி",
    "ramanathapuram": "இராமநாதபுரம்",
    "karur": "கரூர்",
    "perambalur": "பெரம்பலூர்",
    "tiruvannamalai": "திருவண்ணாமலை",
    "cuddalore": "கடலூர்",
    "nagapattinam": "நாகப்பட்டினம்",
    "tiruvarur": "திருவாரூர்",
    "pudukkottai": "புதுக்கோட்டை",
    "viluppuram": "விழுப்புரம்",
    "kancheepuram": "காஞ்சிபுரம்",
    "ariyalur": "அரியலூர்",
    "nilgiris": "நீலகிரி",
    "theni": "தேனி",
    "thiruvallur": "திருவள்ளூர்",
    "tenkasi": "தேன்காசி",
    "tiruvallur": "திருவள்ளூர்",
    "ranipet": "ராணிப்பேட்டை",
    "kallakurichi": "கள்ளக்குறிச்சி",
    "andhra pradesh": "ஆந்திரப்பிரதேசம்",
    "arunachal pradesh": "அருணாசலபிரதேசம்",
    "assam": "அசாம்",
    "bihar": "பிஹார்",
    "chhattisgarh": "சத்தியாகர்த்திரம்",
    "goa": "கோவா",
    "gujarat": "குஜராத்து",
    "haryana": "ஹரியானா",
    "himachal pradesh": "ஹிமாச்சலபிரதேசம்",
    "jharkhand": "ஜார்கண்ட்",
    "karnataka": "கர்நாடகா",
    "kerala": "கேரளா",
    "madhya Pradesh": "மத்திய பிரதேசம்",
    "maharashtra": "மஹாராஷ்டிரா",
    "manipur": "மணிப்பூர்",
    "meghalaya": "மெகாலயா",
    "mizoram": "மிசோரம்",
    "nagaland": "நாகாலாந்து",
    "odisha": "ஒடிசா",
    "punjab": "பஞ்சாப்",
    "rajasthan": "ராஜஸ்தான்",
    "sikkim": "சிக்கிம்",
    "tamil nadu": "தமிழ்நாடு",
    "telangana": "தெலங்கானா",
    "tripura": "திரிபுரா",
    "uttar pradesh": "உத்தரபிரதேசம்",
    "uttarakhand": "உத்தராஞ்சலபிரதேசம்",
    "west bengal": "மேற்கு பங்களாதேசம்",
    "rice": "அரிசி",
    "wheat": "கோதுமை",
    "maize": "மக்காச்சோளம்",
    "millets": "தினைகள்",
    "barley": "பார்லி",
    "sorghum": "சோளம்",
    "bajra": "கம்பு",
    "ragi": "கேழ்வரகு",
    "jowar": "சோளம்",
    "cotton": "காட்டன்",
    "sugarcane": "கரும்பு",
    "groundnut": "வேர்க்கடலை",
    "sunflower": "சூரியகாந்தி",
    "mustard": "கடுகு",
    "sesame": "எள்",
    "soybean": "சோயாபீன்",
    "peas": "பட்டாணி",
    "chickpeas": "கொண்டைக்கடலை",
    "green Gram": "பச்சை பயறு",
    "black Gram": "உளுந்து",
    "red Gram": "துவரம்பருப்பு",
    "horse Gram": "கேழ்வரகு",
    "pigeon Pea": "துவரை",
    "tomato": "தக்காளி",
    "potato": "உருளைக்கிழங்கு",
    "onion": "வெங்காயம்",
    "garlic": "பூண்டு",
    "ginger": "இஞ்சி",
    "carrot": "காரட்",
    "cabbage": "முட்டைக்கோசு",
    "cauliflower": "காலிபிளவர்",
    "brinjal": "கத்திரிக்காய்",
    "capsicum": "குடைமிளகாய்",
    "pumpkin": "பூசணிக்காய்",
    "watermelon": "தர்பூசணிக்காய்",
    "mango": "மாம்பழம்",
     "banyan tree": "ஆல மரம்",
    "neem tree": "வேம்பு மரம்",
    "coconut tree": "தேங்காய் மரம்",
    "mango tree": "மாம்பழ மரம்",
    "teak tree": "தேக்கு மரம்",
    "peepal tree": "அரச மரம்",
    "jamun tree": "நாவல் மரம்",
    "palm tree": "பனை மரம்",
    "gulmohar tree": "சேம்பருத்தி மரம்",
    "bamboo tree": "மூங்கில் மரம்",
    "cashew tree": "முந்திரி மரம்",
    "jackfruit tree": "பலாப்பழம் மரம்",
    "teak tree": "தேக்கு மரம்",
    "sandalwood tree": "சந்தன மரம்",
    "tamarind tree": "புளி மரம்",
    "pine tree": "பைன் மரம்",
    "cypress tree": "சிப்ரஸ் மரம்",
    "magnolia tree": "மேக்நோலியா மரம்",
    "olive tree": "ஆலிவ் மரம்",
    "apple tree": "ஆப்பிள் மரம்",
    "papaya tree": "பப்பாளி மரம்"}

# %%
k_key=[]
for i in k_word.keys():
  k_key.append(i.strip())

# %%
k_key
# Out:
# ['word',
#  'hello',
#  'world',
#  'goodbye',
#  'thank you',
#  'please',
#  'yes',
#  'no',
#  'happy',
#  'sad',
#  'love',
#  'friend',
#  'family',
#  'home',
#  'work',
#  'play',
#  'eat',
#  'drink',
#  'sleep',
#  'run',
#  'walk',
#  'jump',
#  'swim',
#  'read',
#  'write',
#  'listen',
#  'speak',
#  'learn',
#  'understand',
#  'think',
#  'create',
#  'imagine',
#  'explore',
#  'discover',
#  'solve',
#  'challenge',
#  'success',
#  'failure',
#  'beautiful',
#  'ugly',
#  'big',
#  'small',
#  'hot',
#  'cold',
#  'bright',
#  'dark',
#  'new',
#  'old',
#  'strong',
#  'weak',
#  'fast',
#  'slow',
#  'smart',
#  'stupid',
#  'brave',
#  'fearful',
#  'kind',
#  'mean',
#  'generous',
#  'selfish',
#  'honest',
#  'dishonest',
#  'healthy',
#  'sick',
#  'clean',
#  'dirty',
#  'simple',
#  'complex',
#  'open',
#  'closed',
#  'empty',
#  'full',
#  'good',
#  'bad',
#  'right',
#  'wrong',
#  'true',
#  'false',
#  'day',
#  'night',
#  'sun',
#  'moon',
# ...

# %%
k_value=[]
for i in k_word.values():
  k_value.append(i.strip())

# %%
k_value
# Out:
# ['சொல்',
#  'வணக்கம்',
#  'உலகம்',
#  'பிரியாவிடம்',
#  'நன்றி',
#  'தயவுசெய்து',
#  'ஆம்',
#  'இல்லை',
#  'மகிழ்ச்சியான',
#  'துக்கமான',
#  'காதல்',
#  'நண்பர்',
#  'குடும்பம்',
#  'வீடு',
#  'வேலை',
#  'விளையாடு',
#  'சாப்பிடு',
#  'குடி',
#  'தூங்கு',
#  'ஓடு',
#  'நட',
#  'ஆடு',
#  'பயணம்',
#  'வாசி',
#  'எழுது',
#  'கேளு',
#  'பேசு',
#  'கற்றுக்கொள்',
#  'புரிந்துகொள்',
#  'சிந்தி',
#  'உருவாக்கு',
#  'கண்டிப்பாக்கு',
#  'ஆராயு',
#  'கண்டறி',
#  'தீர்',
#  'சவால்',
#  'வெற்றி',
#  'தோல்வி',
#  'அழகான',
#  'மீண்டும்',
#  'பெரிய',
#  'சிறிய',
#  'சூடான',
#  'சீண்டு',
#  'ஒளிர',
#  'இருக்காத',
#  'புதிய',
#  'பழைய',
#  'வலிமையான',
#  'மெதுவான',
#  'வேகமான',
#  'மெதுவான',
#  'போன்ற',
#  'முட்டாள்தனமான',
#  'தடையில்லாத',
#  'பயமுடன்',
#  'அன்புள்ள',
#  'மேன்',
#  'உதவி',
#  'சொந்த',
#  'நேர்மையான',
#  'மொழி',
#  'ஆரோக்கிய',
#  'நீரிழிவு',
#  'தொலைந்த',
#  'கழுவும்',
#  'எளிதான',
#  'சூழ்நிலையான',
#  'திறந்த',
#  'மூடப்பட்ட',
#  'காலியான',
#  'முழுவதும்',
#  'நலமான',
# ...

# %%
k_word={k_key[i]:k_value[i] for i in range(len(k_key))}

# %%
k_word
# Out:
# {'word': 'சொல்',
#  'hello': 'வணக்கம்',
#  'world': 'உலகம்',
#  'goodbye': 'பிரியாவிடம்',
#  'thank you': 'நன்றி',
#  'please': 'தயவுசெய்து',
#  'yes': 'ஆம்',
#  'no': 'இல்லை',
#  'happy': 'மகிழ்ச்சியான',
#  'sad': 'துக்கமான',
#  'love': 'காதல்',
#  'friend': 'நண்பர்',
#  'family': 'குடும்பம்',
#  'home': 'வீடு',
#  'work': 'வேலை',
#  'play': 'விளையாடு',
#  'eat': 'சாப்பிடு',
#  'drink': 'குடி',
#  'sleep': 'தூங்கு',
#  'run': 'ஓடு',
#  'walk': 'நட',
#  'jump': 'ஆடு',
#  'swim': 'பயணம்',
#  'read': 'வாசி',
#  'write': 'எழுது',
#  'listen': 'கேளு',
#  'speak': 'பேசு',
#  'learn': 'கற்றுக்கொள்',
#  'understand': 'புரிந்துகொள்',
#  'think': 'சிந்தி',
#  'create': 'உருவாக்கு',
#  'imagine': 'கண்டிப்பாக்கு',
#  'explore': 'ஆராயு',
#  'discover': 'கண்டறி',
#  'solve': 'தீர்',
#  'challenge': 'சவால்',
#  'success': 'வெற்றி',
#  'failure': 'தோல்வி',
#  'beautiful': 'அழகான',
#  'ugly': 'மீண்டும்',
#  'big': 'பெரிய',
#  'small': 'சிறிய',
#  'hot': 'சூடான',
#  'cold': 'சீண்டு',
# ...

# %%
word=(h_word | k_word)

# %%
print(word)
# Out:
# {'I': 'நான்', 'Am': 'நான்', 'Do': 'செய்', 'Go': 'போ', 'He': 'அவர்', 'Me': 'என்னை', 'My': 'என்', 'No': 'இல்லை', 'On': 'அன்று', 'Or': 'அல்லது', 'So': 'அதனால்', 'Up': 'வரை', 'We': 'நாங்கள்', 'Act': 'நாடகம்', 'Add': 'கூட்டு', 'Age': 'வயது', 'Aim': 'நோக்கம்', 'Air': 'காற்று', 'All': 'அனைத்து', 'And': 'மற்றும்', 'Ant': 'எறும்பு', 'Any': 'ஏதேனும்', 'Ask': 'கேட்க', 'Bad': 'மோசமான', 'Big': 'பெரிய', 'Buy': 'வாங்க', 'Cry': 'கலங்குவது', 'Dam': 'அணை', 'Dry': 'இறக்கின்றன', 'Die': 'உலர்', 'End': 'முடிவு', 'Ear': 'காது', 'Eat': 'சாப்பிடு', 'Egg': 'முட்டை', 'Eye': 'கண்', 'Fat': 'கொழுப்பு', 'Fly': 'ஈ', 'Fun': 'வேடிக்கை', 'Get': 'பெறு', 'God': 'இறைவன்', 'Hen': 'கோழி', 'Hot': 'சூடான', 'Job': 'வேலை', 'Leg': 'கால்', 'Lie': 'பொய்', 'Low': 'குறைந்த', 'Mad': 'பைத்தியம்', 'Man': 'மனிதன்', 'Not': 'இல்லை', 'Now': 'இப்போது', 'New': 'புதிய', 'Old': 'பழைய', 'Own': 'சொந்தம்', 'Run': 'ஓடு', 'Sad': 'வருத்தம்', 'Sea': 'கடல்', 'See': 'பார்க்க', 'Shy': 'கூச்சமுடைய', 'Sit': 'உட்கார', 'Sum': 'தொகை', 'Sun': 'சூரியன்', 'T
# ...

# %%
len(word)
# Out:
# 1007

# %%
word.get('Or')
# Out:
# 'அல்லது'

# %%
word.get('healthy')
# Out:
# 'ஆரோக்கிய'

# %%
word.get('mathematics')
# Out:
# 'கணிதம்'
