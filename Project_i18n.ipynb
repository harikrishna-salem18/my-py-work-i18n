# %%
#504 most important common words in Tamil language and their pronunciation in English.

# %%
basic_words = {'I':'நான்',
         'Am':'நான் ' ,
         'Do':'செய்' ,
         'Go':'போ' ,
         'He':'அவர்' ,
         'Me':'என்னை' ,
         'My':'என்' ,
         'No':'இல்லை' ,
         'On':'அன்று' ,
         'Or':'அல்லது' ,
         'So':'அதனால்' ,
         'Up':'	வரை' ,
         'We':'நாங்கள்' ,
         'Act':'நாடகம்' ,
         'Add':'கூட்டு' ,
         'Age':'வயது' ,
         'Aim':'நோக்கம்' ,
         'Air':'காற்று' ,
         'All':'அனைத்து' ,
         'And':'மற்றும்' ,
         'Ant':'எறும்பு' ,
         'Any':'ஏதேனும்' , 
         'Ask':'கேட்க' ,
         'Bad':'மோசமான' ,
         'Big':'பெரிய' ,
         'Buy':'வாங்க' ,
         'Cry':'கலங்குவது' ,
         'Dam':'அணை' ,
         'Dry':'இறக்கின்றன' ,
         'Die':'உலர்' ,
         'End':'முடிவு' ,
         'Ear':'காது' ,
         'Eat':'சாப்பிடு' ,
         'Egg':'முட்டை' ,
         'Eye':'கண்' ,
         'Fat':'கொழுப்பு' ,
         'Fly':'ஈ' ,
         'Fun':'வேடிக்கை' ,
         'Get':'பெறு' ,
         'God':'இறைவன்' ,
         'Hen':'கோழி' ,
         'Hot':'சூடான' ,
         'Job':'வேலை' ,
         'Leg':'கால்' ,
         'Lie':'பொய்' ,
         'Low':'குறைந்த' ,
         'Mad':'பைத்தியம்' ,
         'Man':'மனிதன்' ,
         'Not':'இல்லை' ,
         'Now':'இப்போது' ,
         'New':'புதிய' ,
         'Old':'பழைய' ,
         'Own':'சொந்தம்' ,
         'Run':'ஓடு' ,
         'Sad':'வருத்தம்' ,
         'Sea':'கடல்' ,
         'See':'பார்க்க' ,
         'Shy':'கூச்சமுடைய' ,
         'Sit':'உட்கார' ,
         'Sum':'தொகை' ,
         'Sun':'சூரியன்' ,
         'Tax':'வரி' , 
         'Try':'முயற்சி' ,
         'Use':'பயன்படுத்த' ,
         'War':'போர்' ,
         'Wet':'ஈரமான' ,
         'Who':'யார்' ,
         'Why':'ஏன்' ,
         'Win':'வெற்றி' ,
         'Also':'மேலும்' ,
         'Baby':'குழந்தை' ,
         'Back':'மீண்டும்' ,
         'Bake':'சுட்டுக்கொள்ள' ,
         'Bald':'வழுக்கை' ,
         'Ball':'பந்து' ,
         'Bark':'பட்டை' ,
         'Bath':'குளியல்' ,
         'Beet':'கிழங்கு' ,
         'Bend':'வளைவு',
         'Best':'சிறந்த' ,
         'Bird':'பறவை' ,
         'Bold':'தைரியமான' ,
         'Bone':'எலும்பு' ,
         'Book':'நூல்' ,
         'Born':'பிறந்தார்' ,
         'Both':'இரண்டும்' ,
         'Busy':'பரபரப்பு' ,
         'Call':'அழைப்பு' ,
         'Calm':'அமைதியான' ,
         'Care':'பராமரிப்பு' ,       
         'Come':'வாருங்கள்' ,
         'Cost':'செலவு' ,
         'Cute':'அழகான' ,
         'Crow':'காகம்' ,
         'Dare':'தைரியம்' ,
         'Dark':'இருள்' ,
         'Date':'தேதி' ,
         'Deal':'ஒப்பந்தம்' ,
         'Diet':'உணவுமுறை' ,
         'Dish':'சிறு தட்டு' ,
         'Door':'கதவு' ,
         'Down':'கீழ்' ,
         'Dust':'தூசி' ,
         'Each':'ஒவ்வொன்றும்' ,
         'Earn':'சம்பாதி' ,
         'Easy':'சுலபம்' ,
         'Edge':'விளிம்பு' ,
         'Evil':'தீய' ,
         'Exit':'வெளியேறு' ,
         'Face':'முகம்' ,
         'Fact':'உண்மை' ,
         'Fair':'நியாயமான' ,
         'Fake':'போலி' ,
         'Farm':'பண்ணை' ,
         'Fast':'வேகமாக' ,
         'Fear':'பயம்' ,
         'Feel':'உணர்கிறேன்' , 
         'Find':'கண்டுபிடிக்க' ,
         'Fine':'நன்றாக' ,
         'Fish':'மீன்' ,
         'Food':'உணவு' ,
         'Fool':'முட்டாள்' ,
         'Free':'இலவசம்' ,
         'Frog':'தவளை' ,
         'Full':'முழு' ,
         'Gape':'இடைவெளி' ,
         'Gift':'பரிசு' , 
         'Girl':'பெண்' ,
         'Goat':'வெள்ளாடு' , 
         'Good':'நல்ல' , 
         'Grab':'பிடி' ,
         'Grow':'வளர' ,
         'Half':'பாதி' ,
         'Hate':'வெறுக்கிறேன்' ,
         'Head':'தலை' ,
         'Hear':'கேள்' , 
         'Heat':'வெப்பம்' ,
         'Help':'உதவி' ,
         'Here':'இங்கே' ,
         'Hide':'மறைக்க' ,
         'High':'உயர்' ,
         'Hold':'பிடி' , 
         'Hole':'துளை' ,
         'Home':'வீடு' ,
         'Huge':'மிகப்பெரிய' ,
         'Hurt':'காயப்படுத்தியது' ,
         'Idea':'யோசனை' ,
         'Jump':'குதிக்க' ,
         'Just':'வெறும்' ,
         'Kill':'கொல்ல' , 
         'Land':'நிலம்' , 
         'Last':'கடந்த' ,
         'Late':'தாமதமாக' ,
         'Left':'விட்டு' ,
         'Life':'வாழ்க்கை' ,
         'Line':'வரி' ,
         'Lion':'சிங்கம்' ,
         'Long':'நீளமானது' ,
         'Look':'பார்' ,
         'Lost':'இழந்தது' ,
         'Love':'அன்பு' ,
         'Luck':'அதிர்ஷ்டம்' ,
         'Lung':'நுரையீரல்' ,
         'Many':'பல' ,
         'Meet':'சந்திக்க' ,
         'Melt':'உருகும்' ,
         'Milk':'பால்' , 
         'Must':'வேண்டும்' ,
         'Name':'பெயர்' ,
         'Near':'அருகில்' ,
         'Neat':'சுத்தமாக' ,
         'Neck':'கழுத்து' ,
         'Need':'தேவை' ,
         'Next':'அடுத்தது' , 
         'Only':'மட்டுமே' , 
         'Pain':'வலி' ,
         'Pair':'ஜோடி' ,
         'Park':'பூங்கா' ,
         'Path':'பாதை' ,
         'Play':'விளையாடு' , 
         'Poor':'ஏழை' ,
         'Pull':'இழுக்க' ,
         'Pure':'தூய்மையான' ,
         'Quit':'விட்டுவிட' ,
         'Quiz':'வினாடி வினா' ,
         'Race':'இனம்' ,
         'Rain':'மழை' ,
         'Rare':'அரிதான' ,
         'Real':'உண்மையான' ,
         'Rent':'வாடகை' ,
         'Rest':'ஓய்வு' , 
         'Rich':'பணக்கார' ,
         'Ride':'சவாரி' ,
         'Rise':'உயர்வு' ,
         'Risk':'ஆபத்து' ,
         'Room':'அறை' ,
         'Rope':'கயிறு' ,
         'Rude':'முரட்டுத்தனமான' ,
         'Sage':'முனிவர்' ,
         'Sail':'படகோட்டம்' ,
         'Salt':'உப்பு' ,
         'Same':'அதே' ,
         'Sand':'மணல்' ,
         'Save':'சேமிக்க' ,
         'Scam':'ஊழல்' ,
         'Seed':'விதை' ,
         'Seek':'தேடுங்கள்' ,
         'Self':'சுய' ,
         'Sell':'விற்க' ,
         'Send':'அனுப்புக' ,
         'Shop':'கடை' ,
         'Show':'நிகழ்ச்சி' ,
         'Sick':'உடம்பு சரியில்லை' ,
         'Side':'பக்கம்' ,
         'Site':'தளம்' ,
         'Size':'அளவு' ,
         'Skin':'தோல்' ,
         'Slow':'மெதுவாக' ,
         'Soft':'மென்மையான' ,
         'Soil':'மண்' ,
         'Some':'சில' ,
         'Soon':'விரைவில்' ,
         'Stay':'தங்க' ,
         'Stop':'நிறுத்து' ,
         'Such':'அத்தகைய' ,
         'Swap':'இடமாற்று' ,
         'Swim':'நீந்த' ,
         'Take':'எடுத்துக்கொள்' ,
         'Talk':'பேசு' ,
         'Tall':'உயரமான' ,
         'Team':'அணி' ,
         'Tell':'சொல்லுங்கள்' ,
         'Tent':'கூடாரம்' ,
         'That':'அந்த' ,
         'Then':'பிறகு' ,
         'Thin':'மெல்லிய' ,    
         'This':'இது' ,
         'Tide':'அலை' ,
         'Time':'நேரம்' ,
         'Tour':'சுற்றுப்பயணம்' ,
         'Town':'நகரம்' ,
         'Tree':'மரம்' ,
         'Trip':'பயணம்' ,
         'Turn':'திரும்ப' ,
         'Ugly':'அசிங்கமான' ,
         'Vase':'குவளை' ,
         'Vein':'நரம்பு' ,
         'Very':'மிகவும்' ,
         'View':'பார்வை' ,
         'Wage':'கூலி' ,
         'Wait':'காத்திரு' ,
         'Wake':'எழுந்திரு' ,
         'Walk':'நட' ,
         'Wall':'சுவர்' ,
         'Want':'வேண்டும்' ,
         'Warm':'சூடான' ,
         'Warn':'எச்சரிக்கை' ,
         'Weak':'பலவீனமான' ,
         'Wear':'அணிய' ,
         'Week':'வாரம்' ,
         'Well':'நன்றாக' ,
         'Went':'சென்றார்' ,
         'What':'என்ன' ,
         'When':'எப்பொழுது' ,
         'Wide':'பரந்த' ,
         'Wife':'மனைவி' ,
         'Wild':'காட்டு' ,
         'Will':'விருப்பம்' ,
         'Wind':'காற்று' ,
         'Wine':'மது' ,
         'Wish':'விரும்பும்' ,
         'Wood':'மரம்' ,
         'Wool':'கம்பளி' ,
         'Word':'சொல்' ,
         'Work':'வேலை' ,
         'Worm':'புழு' ,
         'Yarn':'நூல்' ,
         'Your':'உங்கள்' ,
         'Zoom':'பெரிதாக்கு' ,
         'About':'பற்றி' ,
         'Above':'மேலே' ,
         'Adapt':'ஏற்ப' ,
         'Admit':'ஒப்புக்கொள்' ,
         'Adult':'வயது வந்தோர்' ,
         'After':'பிறகு' ,
         'Again':'மீண்டும்' ,
         'Agree':'ஒப்புக்கொள்' ,
         'Alert':'எச்சரிக்கை' ,
         'Allow':'அனுமதிக்க' ,
         'Alone':'தனியாக' ,
         'Along':'சேர்த்து' ,
         'Anger':'கோபம்' ,
         'Angle':'கோணம்' ,
         'Angry':'கோபம்' ,
         'Asset':'சொத்து' ,
         'Avoid':'தவிர்க்க' ,
         'Awake':'விழித்து' ,
         'Aware':'தெரியும்' ,
         'Begin':'தொடங்கும்' ,
         'Birth':'பிறப்பு' ,
         'Blood':'இரத்தம்' ,
         'Brain':'மூளை' ,
         'Built':'கட்டப்பட்டது' ,
         'Bring':'கொண்டு' ,
         'Build':'கட்ட' ,
         'Camel':'ஒட்டகம்' ,
         'Canal':'கால்வாய்' ,
         'Carry':'சுமந்து செல்' ,
         'Cheap':'மலிவான' ,
         'Cheat':'ஏமாற்று' ,
         'Check':'காசோலை' ,
         'Chest':'மார்பு' ,
         'Claim':'கூற்று' ,
         'Clean':'சுத்தமான' ,
         'Clear':'தெளிவானது' ,
         'Climb':'ஏற' ,
         'Close':'நெருக்கமான' ,
         'Cloth':'துணி' ,
         'Cloud':'மேகம்' ,
         'Color':'நிறம்' ,
         'Crime':'குற்றம்' ,
         'Crowd':'கூட்டம்' ,
         'Crown':'கிரீடம்' ,
         'Daily':'தினசரி' ,
         'Dance':'நடனம்' ,
         'Death':'இறப்பு' ,
         'Decay':'சிதைவு' ,
         'Delay':'தாமதம்' ,
         'Devil':'பிசாசு' ,
         'Dirty':'அழுக்கு' ,
         'Dress':'ஆடை' ,
         'Drink':'பானம்' ,
         'Drive':'ஓட்டு' ,
         'Dwell':'வசிக்க' ,
         'Eager':'ஆவலுடன்' ,
         'Eagle':'கழுகு' ,
         'Early':'ஆரம்ப' ,
         'Earth':'பூமி' ,
         'Elder':'மூத்தவர்' ,
         'Empty':'காலியாக' ,
         'Enemy':'எதிரி' ,
         'Enjoy':'அனுபவிக்க' ,
         'Entry':'நுழைவு' ,
         'Equal':'சமமான' ,
         'Essay':'கட்டுரை' ,
         'Event':'நிகழ்வு' ,
         'Every':'ஒவ்வொரு' ,
         'Exact':'சரியான' ,
         'Exist':'உள்ளன' ,
         'Extra':'கூடுதல்' ,
         'Faith':'நம்பிக்கை' ,
         'Fault':'தவறு' ,
         'Fever':'காய்ச்சல்' ,
         'Field':'களம்' ,
         'Final':'இறுதி' ,
         'Fleet':'கடற்படை' ,
         'Float':'மிதவை' ,
         'Flood':'வெள்ளம்' ,
         'Floor':'தரை' ,
         'Flour':'மாவு' ,
         'Fluid':'திரவம்' ,
         'Focus':'கவனம்' ,
         'Force':'படை' ,
         'Fraud':'மோசடி' ,
         'Fresh':'புதியது' ,
         'Front':'முன்' ,
         'Fruit':'பழம்' ,
         'Ghost':'பேய்' ,
         'Globe':'பூகோளம்' ,
         'Going':'போகிறது' ,
         'Grain':'தானியம்' ,
         'Grant':'மானியம்' ,
         'Grass':'புல்' ,
         'Great':'நன்று' ,
         'Group':'குழு' ,
         'Guard':'காவலர்' ,
         'Guest':'விருந்தினர்' ,
         'Habit':'பழக்கம்' ,
         'Heart':'இதயம்' ,
         'Honey':'தேன்' ,
         'Horse':'குதிரை' ,
         'House':'வீடு' ,
         'Human':'மனிதன்' ,
         'Ideal':'ஏற்றதாக' ,
         'Issue':'பிரச்சினை' ,
         'Judge':'நீதிபதி' , 
         'Knife':'கத்தி' ,
         'Labor':'தொழிலாளர்' , 
         'Ladle':'அகப்பை' ,
         'Large':'பெரிய' ,
         'Laugh':'சிரிக்கவும்' ,
         'Learn':'அறிய' ,
         'Leave':'விடு' ,
         'Legal':'சட்டபூர்வமான' ,
         'Limit':'அளவு' ,
         'Lunch':'மதிய உணவு' ,
         'Metal':'உலோகம்' ,
         'Mixed':'கலந்தது' ,
         'Money':'பணம்' ,
         'Month':'மாதம்' ,
         'Mount':'ஏற்ற' ,
         'Mouth':'வாய்' ,
         'Music':'இசை' ,
         'Maize':'சோளம்' ,
         'Naked':'நிர்வாணமாக' ,
         'Never':'ஒருபோதும்' ,
         'Night':'இரவு' ,
         'Niece':'மருமகள்' ,
         'Noise':'சத்தம்' ,
         'Occur':'ஏற்படும்' ,
         'Ocean':'கடல்' ,
         'Onion':'வெங்காயம்' ,
         'Offer':'சலுகை' ,
         'Order':'உத்தரவு' ,
         'Organ':'உறுப்பு' ,
         'Other':'மற்றவை' ,
         'Owner':'உரிமையாளர்' ,
         'Paddy':'நெல்' ,
         'Panic':'பீதி' ,
         'Peace':'சமாதானம்' ,
         'Place':'இடம்' ,
         'Plant':'ஆலை' ,
         'Price':'விலை' ,
         'Pride':'பெருமை' ,
         'Proud':'பெருமை' ,
         'Prove':'நிரூபிக்க' , 
         'Quilt':'மெல்லிய மெத்தை' ,
         'Quick':'விரைவான' ,
         'Quite':'மிகவும்' ,
         'Raise':'உயர்த்த' ,
         'Reach':'அடைய' ,
         'React':'எதிர்வினை' ,
         'Ready':'தயார்' ,
         'Reply':'பதில்' ,
         'Right':'சரி' ,
         'Round':'சுற்று' ,
         'Rural':'கிராமப்புற' ,
         'Saint':'புனிதர்' ,
         'Scope':'வாய்ப்பு' ,
         'Score':'மதிப்பெண்' ,
         'Sense':'உணர்வு' ,
         'Shake':'குலுக்கல்' ,
         'Shape':'வடிவம்' ,
         'Share':'பகிர்' ,
         'Sharp':'கூர்மையான' ,
         'Shrub':'புதர்' ,
         'Skill':'திறமை' ,
         'Sleep':'தூங்கு' ,
         'Slope':'சாய்வு' ,
         'Small':'சிறிய' ,
         'Smell':'வாசனை' ,
         'Smile':'புன்னகை' ,
         'Snake':'பாம்பு' ,
         'Snore':'குறட்டை' ,
         'Solid':'திடமான' ,
         'Sound':'ஒலி' ,
         'Space':'விண்வெளி' ,
         'Speak':'பேசு' ,
         'Speed':'வேகம்' ,
         'Spend':'செலவு' ,
         'Spent':'செலவழித்தது' ,
         'Sperm':'விந்து' ,
         'Sport':'விளையாட்டு' , 
         'Stand':'நிற்க' ,
         'Steam':'நீராவி' ,
         'Stone':'கல்' ,
         'Story':'கதை' ,
         'Taste':'சுவை' ,
         'Teach':'கற்பிக்கின்றன' ,
         'Teeth':'பற்கள்' ,
         'Thank':'நன்றி' ,
         'There':'அங்கு' ,
         'These':'இவை' ,
         'Thick':'தடித்த' , 
         'Thing':'விஷயம்' ,
         'Tiger':'புலி' ,
         'Today':'இன்று' ,
         'Total':'மொத்தம்' ,
         'Treat':'சிகிச்சை' ,
         'Trend':'போக்கு' ,
         'Tried':'முயற்சித்தார்' ,
         'Trust':'நம்பிக்கை' ,
         'Truth':'உண்மை' ,
         'Twice':'இரண்டு முறை' ,
         'Under':'கீழ்' ,
         'Upper':'மேல்' ,
         'Urban':'நகர்ப்புற' ,
         'Visit':'வருகை' ,
         'Voice':'குரல்' ,
         'Vomit':'வாந்தி' ,
         'Waste':'கழிவு' ,
         'Water':'தண்ணீர்' ,
         'Wheat':'கோதுமை' ,
         'Where':'எங்கே' ,
         'White':'வெள்ளை' ,
         'Whole':'முழுவதும்' ,
         'Woman':'பெண்' ,
         'World':'உலகம்' ,
         'Worst':'மோசமான' ,
         'Write':'எழுது' ,
         'Wrong':'தவறு' ,
         'Yield':'விளைச்சல்' ,
         'Young':'இளம்' ,
         'Youth':'இளைஞர்கள்'}

# %%
#Enter any word from the given 504 words with first letter uppercase and correct spelling and get it's Tamil translation

# %%
search_basic_words = input('Enter word: ')
print(word.get(search_basic_words, 'Word Not Found. '))
# Out:
# Enter word: Youth
# இளைஞர்கள்

# %%
len(word)
# Out:
# 504
